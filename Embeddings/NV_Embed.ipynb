# %% [markdown]
# # 1. Install Required Packages

# %%
# !pip install transformers

# %%
# !pip install einops datasets

# %%
#required accessing some models

#!pip install -U "huggingface_hub[cli]"
#!huggingface-cli login

# %% [markdown]
# # 2. Load Model

# %%
import torch
import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel

# %%
# load model with tokenizer
model = AutoModel.from_pretrained('nvidia/NV-Embed-v1', trust_remote_code=True)

# %% [markdown]
# # 3. Encode sentences

# %%
# Each query needs to be accompanied by an corresponding instruction describing the task.

queries = [
    'are judo throws allowed in wrestling?',
    'how to become a radiology technician in michigan?'
    ]

# %%
# get the embeddings
max_length = 4096

query_embeddings = model.encode(queries, max_length=max_length)

# normalize embeddings
query_embeddings = F.normalize(query_embeddings, p=2, dim=1)
# Out:
# /root/.cache/huggingface/modules/transformers_modules/nvidia/NV-Embed-v1/97aefcdd69565404f4a24de8ca4eb8114cb25ff0/modeling_nvembed.py:345: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(batch_dict.get('input_ids').to(batch_dict.get('input_ids')).long()),
# /usr/local/lib/python3.10/dist-packages/torch/backends/cuda/__init__.py:342: FutureWarning: torch.backends.cuda.sdp_kernel() is deprecated. In the future, this context manager will be removed. Please see, torch.nn.attention.sdpa_kernel() for the new context manager, with updated signature.
#   warnings.warn(

# %%
query_embeddings
